# %% [markdown]
# <a href="https://colab.research.google.com/github/OheneBoateng/HTM737-OHENE/blob/main/Week12%20code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
X_train = pd.read_csv('https://raw.githubusercontent.com/osoliman/Chapter7_HTM737/refs/heads/main/X_train_clean.csv')
X_test = pd.read_csv('https://raw.githubusercontent.com/osoliman/Chapter7_HTM737/refs/heads/main/X_test_clean.csv')
y_train = pd.read_csv('https://raw.githubusercontent.com/osoliman/Chapter7_HTM737/refs/heads/main/y_train.csv')
y_test = pd.read_csv('https://raw.githubusercontent.com/osoliman/Chapter7_HTM737/refs/heads/main/y_test.csv')

y_train = y_train.values.ravel()

# %%
X_train.head()
# Out:
#    WAITTIME  AGE  WINTER  NIGHT  SEX
# 0        44   21       0      1    1
# 1        -9   45       0      1    1
# 2        64   55       0      0    2
# 3        -7   32       0      0    1
# 4        13   23       1      1    1

# %% [markdown]
# # **Logistic Regression**

# %% [markdown]
# **Building the model**
#
# only 3 lines needed
#
# 1- import [model]
#
# 2- define the model
#
# 3 fit the model

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# **Evaluating the model**
#
# Predict the probabilities in the *test* set

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_test, y_pred)
print(f'accuracy is {accuracy:.1%}')
# Out:
# accuracy is 86.8%

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93      5378
#            1       0.00      0.00      0.00       817
#
#     accuracy                           0.87      6195
#    macro avg       0.43      0.50      0.46      6195
# weighted avg       0.75      0.87      0.81      6195

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[5375    3]
#  [ 817    0]]

# %%
from sklearn.metrics import roc_auc_score

y_pred_proba = model.predict_proba(X_test)
auc = roc_auc_score(y_test, y_pred_proba[:, 1])
print(f'AUC: {auc:.3f}')
# Out:
# AUC: 0.724

# %%
from sklearn.metrics import RocCurveDisplay

RocCurveDisplay.from_estimator(model, X_test, y_test)

# %% [markdown]
# Now your turn to do
#
# **Random Forest**
#
# from sklearn.ensemble import RandomForestClassifier
#
# model = RandomForestClassifier()
#
# model.fit(X_train, y_train)
#
# **Support Vector Machine**
#
# from sklearn.svm import SVC
#
# model = SVC(probability=True)  # probability=True enables predict_proba()
#
# model.fit(X_train, y_train)
#
# **Neural Network**
#
# from sklearn.neural_network import MLPClassifier
#
# model = MLPClassifier()
#
# model.fit(X_train, y_train)

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(X_test)

# %%
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_test, y_pred)
print(f'accuracy is {accuracy:.1%}')
# Out:
# accuracy is 86.8%

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93      5378
#            1       0.00      0.00      0.00       817
#
#     accuracy                           0.87      6195
#    macro avg       0.43      0.50      0.46      6195
# weighted avg       0.75      0.87      0.81      6195

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[5375    3]
#  [ 817    0]]

# %%
from sklearn.metrics import roc_auc_score

y_pred_proba = model.predict_proba(X_test)
auc = roc_auc_score(y_test, y_pred_proba[:, 1])
print(f'AUC: {auc:.3f}')
# Out:
# AUC: 0.724

# %%
from sklearn.metrics import RocCurveDisplay

RocCurveDisplay.from_estimator(model, X_test, y_test)

# %%
X_test.head()
# Out:
#    WAITTIME  AGE  WINTER  NIGHT  SEX
# 0         0   72       0      0    2
# 1        -7    2       0      0    2
# 2         1   40       0      1    1
# 3        52   21       0      0    2
# 4        -9   54       0      0    1

# %%
first_positive_idx = (y_pred == 1).argmax()

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier()

model.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = model.predict(X_test)#Uses the trained logistic regression model to predict class labels for X_test.

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))#Prints precision, recall, f1-score, and support for each class.
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.93      0.90      5378
#            1       0.26      0.16      0.20       817
#
#     accuracy                           0.83      6195
#    macro avg       0.57      0.55      0.55      6195
# weighted avg       0.80      0.83      0.81      6195

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pred)
print(cm)#Computes and prints the confusion matrix to show true vs. predicted class counts.
# Out:
# [[4998  380]
#  [ 683  134]]

# %%
from sklearn.metrics import roc_auc_score

y_pred_proba = model.predict_proba(X_test)
auc = roc_auc_score(y_test, y_pred_proba[:, 1])
print(f'AUC: {auc:.3f}')#Computes predicted probabilities, then calculates and prints ROC AUC.
# Out:
# AUC: 0.651

# %%
from sklearn.metrics import RocCurveDisplay

RocCurveDisplay.from_estimator(model, X_test, y_test)#Uses RocCurveDisplay to generate and show an ROC curve for the model.

# %%
from sklearn.inspection import PartialDependenceDisplay

PartialDependenceDisplay.from_estimator(model, X_train, ['AGE'])

# %%
from sklearn.inspection import PartialDependenceDisplay

PartialDependenceDisplay.from_estimator(model, X_train, ['AGE'])#Partial dependence plot showing how “AGE” influences model predictions.

# %%
import matplotlib.pyplot as plt

plt.barh(X_train.columns, model.feature_importances_)
plt.xlabel('Importance')
plt.show()#Plots a horizontal bar chart showing feature importances (works for tree-based models, but included here).

# %%
from sklearn.svm import SVC

model = SVC(probability=True)

model.fit(X_train, y_train)#Imports SVC, creates a model with probability=True, and fits it on the training data.
# Out:
# SVC(probability=True)

# %%
y_pred = model.predict(X_test)#Generates class predictions for X_test using the SVM model.

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_test, y_pred)
print(f'accuracy is {accuracy:.1%}')#Computes and prints accuracy for the SVM model.
# Out:
# accuracy is 86.8%

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))#Shows precision, recall, f1-score, and support for each class using SVM predictions.
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93      5378
#            1       0.00      0.00      0.00       817
#
#     accuracy                           0.87      6195
#    macro avg       0.43      0.50      0.46      6195
# weighted avg       0.75      0.87      0.81      6195
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pred)
print(cm)#Computes confusion matrix for the SVM model.
# Out:
# [[5378    0]
#  [ 817    0]]

# %%
from sklearn.metrics import roc_auc_score

y_pred_proba = model.predict_proba(X_test)
auc = roc_auc_score(y_test, y_pred_proba[:, 1])
print(f'AUC: {auc:.3f}')#Uses SVM probabilities to compute and print ROC AUC.
# Out:
# AUC: 0.477

# %%
from sklearn.metrics import RocCurveDisplay

RocCurveDisplay.from_estimator(model, X_test, y_test)# Plots an ROC curve for the SVM model.

# %%
from sklearn.neural_network import MLPClassifier

model = MLPClassifier()

model.fit(X_train, y_train)#Creates an MLPClassifier model and fits it to the training data.
# Out:
# MLPClassifier()

# %%
y_pred = model.predict(X_test)#Predicts class labels for X_test using the MLP model.

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_test, y_pred)
print(f'accuracy is {accuracy:.1%}')#Computes and prints test accuracy for the MLP model.
# Out:
# accuracy is 86.9%

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))#Prints precision, recall, and f1-score for neural network predictions.
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93      5378
#            1       0.56      0.03      0.05       817
#
#     accuracy                           0.87      6195
#    macro avg       0.72      0.51      0.49      6195
# weighted avg       0.83      0.87      0.81      6195

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pred)
print(cm)#Prints confusion matrix for the neural network.
# Out:
# [[5360   18]
#  [ 794   23]]

# %%
from sklearn.metrics import roc_auc_score

y_pred_proba = model.predict_proba(X_test)
auc = roc_auc_score(y_test, y_pred_proba[:, 1])
print(f'AUC: {auc:.3f}') #Calculates ROC AUC using predicted probabilities from the neural network.
# Out:
# AUC: 0.721

# %%
from sklearn.metrics import RocCurveDisplay

RocCurveDisplay.from_estimator(model, X_test, y_test)#Plots the ROC curve for the neural network model.
